# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
from tensorflow.keras.datasets import mnist
(X_train, Y_train), (X_test, Y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 1s 0us/step

# %%
X_train = X_train/255.0
# Out:
# 1.0

# %%
X_test = X_test/255.0

# %%
model= tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(10,activation='softmax')    
])

# %%
model.compile(optimizer='adam',
             loss = 'sparse_categorical_crossentropy',
             metrics=['accuracy'])

# %%
r = model.fit(X_train, Y_train, validation_data=(X_test, Y_test),epochs = 10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.2924 - accuracy: 0.9152 - val_loss: 0.1377 - val_accuracy: 0.9605
# Epoch 2/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1420 - accuracy: 0.9577 - val_loss: 0.1098 - val_accuracy: 0.9674
# Epoch 3/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1077 - accuracy: 0.9673 - val_loss: 0.0841 - val_accuracy: 0.9751
# Epoch 4/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0862 - accuracy: 0.9736 - val_loss: 0.0815 - val_accuracy: 0.9765
# Epoch 5/10
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0735 - accuracy: 0.9762 - val_loss: 0.0768 - val_accuracy: 0.9763
# Epoch 6/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0651 - accuracy: 0.9791 - val_loss: 0.0724 - val_accuracy: 0.9793
# Epoch 7/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0556 - accuracy: 0.9822 - val_loss: 0.0709 - val_accuracy: 0.9793
# Epoch 8/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0514 - accuracy: 0.9833 - val_loss: 0.0714 - val_accuracy: 0.9776
# Epoch 9/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0487 - accuracy: 0.9836 - val_loss: 0.0717 - val_accuracy: 0.9801
# Epoch 10/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0458 - accuracy: 0.9847 - val_loss: 0.0704 - val_accuracy: 0.9797

# %%
model.evaluate(X_test,Y_test)
model.predict(X_test)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0704 - accuracy: 0.9797
# array([[7.59867169e-12, 1.19814436e-10, 3.45442110e-08, ...,
#         9.99991059e-01, 1.02633979e-09, 2.38182474e-06],
#        [4.61615191e-11, 9.94482616e-06, 9.99982119e-01, ...,
#         2.15231720e-16, 7.64353558e-08, 2.37361981e-21],
#        [1.38085426e-07, 9.99654531e-01, 2.41778434e-05, ...,
#         1.15683804e-04, 1.85865225e-04, 7.73593882e-08],
#        ...,
#        [3.01935376e-16, 3.00262744e-14, 4.76212819e-13, ...,
#         2.43133809e-06, 1.57382587e-07, 4.15374961e-05],
#        [2.83704016e-09, 4.64855801e-12, 2.71478905e-14, ...,
#         3.87273276e-13, 4.73591936e-04, 3.54200037e-11],
#        [1.62253677e-09, 2.11994983e-15, 5.99027583e-09, ...,
#         1.09327572e-18, 5.37113323e-13, 1.08877480e-14]], dtype=float32)

# %%
plt.plot(r.history['loss'],label='loss')
plt.plot(r.history['val_loss'],label='val_loss')
plt.legend()

# %%
plt.plot(r.history['accuracy'],label='accuracy')
plt.plot(r.history['val_accuracy'],label='val_acc')
plt.legend()

# %%
from sklearn.metrics import confusion_matrix
import itertools

def plot_confusion_matrix(cm,classes,normalize=False,title='Confusion matrix',
                         cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float')/cm.sum(axis=1)[:,np.newaxis]
        print('Normalized confusion matrix')
    else:
        print('Confusion matrix without normalization')
    
    print(cm)
    
    plt.imshow(cm, interpolation= 'nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks,classes,rotation=45)
    plt.yticks(tick_marks,classes)
    
    fmt = '2f' if normalize else 'd'
    thresh =cm.max() /2.
    for i,j in itertools.product(range(cm.shape[0]),range(cm.shape[1])):
        plt.text(j,i, format(cm[i,j],fmt),
                 horizontalalignment='center',
                color='white' if cm[i,j] > thresh else 'black')
    
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()
    
P_test = model.predict(X_test).argmax(axis=1)
cm = confusion_matrix(Y_test, P_test)
plot_confusion_matrix(cm, list(range(10)))
# Out:
# Confusion matrix without normalization
# [[ 974    0    2    0    0    1    1    1    1    0]
#  [   0 1115    3    2    0    0    2    0   13    0]
#  [   6    0 1013    5    0    0    2    4    2    0]
#  [   0    0    3  998    0    2    0    4    2    1]
#  [   2    0    2    0  956    1    3    1    2   15]
#  [   3    0    0   17    1  860    4    1    4    2]
#  [   6    2    2    1    1    4  942    0    0    0]
#  [   2    2   12    3    0    0    0 1003    2    4]
#  [   5    0    3    4    4    0    4    2  948    4]
#  [   1    2    0    8    2    2    2    2    2  988]]

# %%
misclassified_idx = np.where(P_test != Y_test)[0]
i = np.random.choice(misclassified_idx)
plt.imshow(X_test[i], cmap='gray')
plt.title('True label: %s Predicted: %s' % (Y_test[i], P_test[i]))
# Out:
# Text(0.5, 1.0, 'True label: 8 Predicted: 6')
